# %%
# set up the python
import cosima_cookbook as cc
from dask.distributed import Client
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import numpy as np
import xarray as xr
import cmocean as cm
import cartopy.crs as ccrs
import cmocean as cm
import cartopy.feature as cft
import cftime
import IPython.display
import sys, os, warnings

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:33639' processes=4 threads=8, memory=32.00 GiB>

# %%
session = cc.database.create_session()

# %%
# set the time period
start_time  = '1995-01-01'
end_time = '2000-01-01'

# %%
# get SST
SST_hycom1 = cc.querying.getvar(expt='panant-01-hycom1-v13', variable='tos', 
                          session=session, frequency='1 daily',
                          start_time='1991-01-01 00:00:00', 
                          end_time='2003-07-01 00:00:00').sel(time = slice(start_time,end_time))

# %%
SST_zstar = cc.querying.getvar(expt='panant-01-zstar-v13', variable='tos', 
                          session=session, frequency='1 daily',
                          start_time='1991-01-01 00:00:00', 
                          end_time='2003-07-01 00:00:00',ncfile='ocean_daily.nc')
# Out:
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<function apply at 0x15189961bd30>, <function open_dataset at 0x1518172d6790>, ['/g/data/ik11/outputs/mom6-panan/panant-01-zstar-v13/output040/20010101.ocean_daily.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [['time', 1], ['yh', 423], ['xh', 1800]])]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<function apply at 0x15189961bd30>, <function open_dataset at 0x1518172d6790>, ['/g/data/ik11/outputs/mom6-panan/panant-01-zstar-v13/output045/20020401.ocean_daily.nc'], (<class 'dict'>, [['engine', None], ['chunks', (<class 'dict'>, [['time', 1], ['yh', 423], ['xh', 1800]])]])))
# kwargs:    {}
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# ---------------------------------------------------------------------------
# ...
